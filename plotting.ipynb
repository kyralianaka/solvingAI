# %%
from model import solvingAI
import numpy as np
import matplotlib.pyplot as plt

# %%
ei = solvingAI()
soln, weights = ei.run_sim()

# %%
time = np.arange(0, ei.T+ei.h, ei.h)
for i in range(20):
    plt.plot(time, soln[i, :])
plt.show()
